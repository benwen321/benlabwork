# %%
# import packages
import os
from PIL import Image
import numpy as np

# import tensorflow as tf
# physical_devices = tf.config.list_physical_devices('GPU')
# print(tf.__version__)
OPENSLIDE_PATH = r'C:\Program Files\openslide-win64-20230414\bin'

os.environ['PATH'] = OPENSLIDE_PATH + ";" + os.environ['PATH']

if hasattr(os, 'add_dll_directory'):
    with os.add_dll_directory(OPENSLIDE_PATH):
        import openslide
else:
    import openslide

from openslide import OpenSlide

# %%
# set output path for 10x and 2x tif images - create directory if they don't exist
WSI_path = r'\\10.17.97.73\kiemen-lab-data\Yu Shen\Venous Invasion\PDAC-FS-7'
path_10x = os.path.join(WSI_path, '5X')

if not os.path.exists(path_10x):
    os.mkdir(path_10x)

# %%
wsis = [_ for _ in os.listdir(WSI_path) if _.endswith('ndpi')]
wsis2 = [os.path.splitext(_)[0] for _ in wsis]
tenx = [_ for _ in os.listdir(path_10x) if _.endswith('tif')]
tenx2 = [os.path.splitext(_)[0] for _ in tenx]
missingimages = [_ for _ in wsis2 if _ not in tenx2]

# %%
for idx, missingimage in enumerate(missingimages):
    print(idx, '/', len(missingimages), ' processing: ', missingimage)
    wsi = OpenSlide(os.path.join(WSI_path, missingimage + '.ndpi'))

    rsf = 2
    svs_img = wsi.read_region(location=(0, 0), level=0, size=wsi.level_dimensions[0]).convert('RGB')
    resize_factorx = rsf / float(wsi.properties['openslide.mpp-x'])  #8um = 1.25x #4um = 2.5x, #2um=5x, 1um=10x, 0.5um=20x, 0.25um=40x
    resize_factory = rsf / float(wsi.properties['openslide.mpp-y'])
    resize_dimension = tuple([int(np.ceil(wsi.dimensions[0] / resize_factorx)), int(np.ceil(wsi.dimensions[1] / resize_factory))])
    svs_img10x = svs_img.resize(resize_dimension, resample=Image.NEAREST)
    svs_img10x.save(os.path.join(path_10x, missingimage + '.tif'), resolution=1, resolution_unit=1, quality=100, compression=None)
# Out:
# 0 / 234  processing:  PDAC_FS-07_001
# 1 / 234  processing:  PDAC_FS-07_004
# 2 / 234  processing:  PDAC_FS-07_007
# 3 / 234  processing:  PDAC_FS-07_010
# 4 / 234  processing:  PDAC_FS-07_013
# 5 / 234  processing:  PDAC_FS-07_016
# 6 / 234  processing:  PDAC_FS-07_019
# 7 / 234  processing:  PDAC_FS-07_022
# 8 / 234  processing:  PDAC_FS-07_025
# 9 / 234  processing:  PDAC_FS-07_028
# 10 / 234  processing:  PDAC_FS-07_031
# 11 / 234  processing:  PDAC_FS-07_034
# 12 / 234  processing:  PDAC_FS-07_037
# 13 / 234  processing:  PDAC_FS-07_040
# 14 / 234  processing:  PDAC_FS-07_043
# 15 / 234  processing:  PDAC_FS-07_046
# 16 / 234  processing:  PDAC_FS-07_049
# 17 / 234  processing:  PDAC_FS-07_052
# 18 / 234  processing:  PDAC_FS-07_055
# 19 / 234  processing:  PDAC_FS-07_058
# 20 / 234  processing:  PDAC_FS-07_061
# 21 / 234  processing:  PDAC_FS-07_064
# 22 / 234  processing:  PDAC_FS-07_067
# 23 / 234  processing:  PDAC_FS-07_070
# 24 / 234  processing:  PDAC_FS-07_073
# 25 / 234  processing:  PDAC_FS-07_076
# 26 / 234  processing:  PDAC_FS-07_079
# 27 / 234  processing:  PDAC_FS-07_082
# 28 / 234  processing:  PDAC_FS-07_085
# 29 / 234  processing:  PDAC_FS-07_088
# 30 / 234  processing:  PDAC_FS-07_091
# 31 / 234  processing:  PDAC_FS-07_094
# 32 / 234  processing:  PDAC_FS-07_097
# 33 / 234  processing:  PDAC_FS-07_100
# 34 / 234  processing:  PDAC_FS-07_103
# 35 / 234  processing:  PDAC_FS-07_106
# 36 / 234  processing:  PDAC_FS-07_109
# 37 / 234  processing:  PDAC_FS-07_112
# 38 / 234  processing:  PDAC_FS-07_115
# 39 / 234  processing:  PDAC_FS-07_118
# 40 / 234  processing:  PDAC_FS-07_121
# 41 / 234  processing:  PDAC_FS-07_124
# 42 / 234  processing:  PDAC_FS-07_127
# 43 / 234  processing:  PDAC_FS-07_130
# 44 / 234  processing:  PDAC_FS-07_133
# 45 / 234  processing:  PDAC_FS-07_136
# 46 / 234  processing:  PDAC_FS-07_139
# 47 / 234  processing:  PDAC_FS-07_142
# 48 / 234  processing:  PDAC_FS-07_145
# 49 / 234  processing:  PDAC_FS-07_148
# 50 / 234  processing:  PDAC_FS-07_151
# 51 / 234  processing:  PDAC_FS-07_154
# 52 / 234  processing:  PDAC_FS-07_157
# 53 / 234  processing:  PDAC_FS-07_160
# 54 / 234  processing:  PDAC_FS-07_163
# 55 / 234  processing:  PDAC_FS-07_166
# 56 / 234  processing:  PDAC_FS-07_169
# 57 / 234  processing:  PDAC_FS-07_172
# 58 / 234  processing:  PDAC_FS-07_175
# 59 / 234  processing:  PDAC_FS-07_178
# 60 / 234  processing:  PDAC_FS-07_181
# 61 / 234  processing:  PDAC_FS-07_184
# 62 / 234  processing:  PDAC_FS-07_187
# 63 / 234  processing:  PDAC_FS-07_190
# 64 / 234  processing:  PDAC_FS-07_193
# 65 / 234  processing:  PDAC_FS-07_196
# 66 / 234  processing:  PDAC_FS-07_199
# 67 / 234  processing:  PDAC_FS-07_202
# 68 / 234  processing:  PDAC_FS-07_205
# 69 / 234  processing:  PDAC_FS-07_208
# 70 / 234  processing:  PDAC_FS-07_211
# 71 / 234  processing:  PDAC_FS-07_214
# 72 / 234  processing:  PDAC_FS-07_217
# 73 / 234  processing:  PDAC_FS-07_220
# 74 / 234  processing:  PDAC_FS-07_223
# 75 / 234  processing:  PDAC_FS-07_226
# 76 / 234  processing:  PDAC_FS-07_229
# 77 / 234  processing:  PDAC_FS-07_232
# 78 / 234  processing:  PDAC_FS-07_235
# 79 / 234  processing:  PDAC_FS-07_238
# 80 / 234  processing:  PDAC_FS-07_241
# 81 / 234  processing:  PDAC_FS-07_244
# 82 / 234  processing:  PDAC_FS-07_247
# 83 / 234  processing:  PDAC_FS-07_250
# 84 / 234  processing:  PDAC_FS-07_253
# 85 / 234  processing:  PDAC_FS-07_256
# 86 / 234  processing:  PDAC_FS-07_259
# 87 / 234  processing:  PDAC_FS-07_262
# 88 / 234  processing:  PDAC_FS-07_265
# 89 / 234  processing:  PDAC_FS-07_268
# 90 / 234  processing:  PDAC_FS-07_271
# 91 / 234  processing:  PDAC_FS-07_274
# 92 / 234  processing:  PDAC_FS-07_277
# 93 / 234  processing:  PDAC_FS-07_280
# 94 / 234  processing:  PDAC_FS-07_283
# 95 / 234  processing:  PDAC_FS-07_286
# 96 / 234  processing:  PDAC_FS-07_289
# 97 / 234  processing:  PDAC_FS-07_292
# 98 / 234  processing:  PDAC_FS-07_295
# 99 / 234  processing:  PDAC_FS-07_298
# 100 / 234  processing:  PDAC_FS-07_301
# 101 / 234  processing:  PDAC_FS-07_304
# 102 / 234  processing:  PDAC_FS-07_307
# 103 / 234  processing:  PDAC_FS-07_310
# 104 / 234  processing:  PDAC_FS-07_313
# 105 / 234  processing:  PDAC_FS-07_316
# 106 / 234  processing:  PDAC_FS-07_319
# 107 / 234  processing:  PDAC_FS-07_322
# 108 / 234  processing:  PDAC_FS-07_325
# 109 / 234  processing:  PDAC_FS-07_328
# 110 / 234  processing:  PDAC_FS-07_331
# 111 / 234  processing:  PDAC_FS-07_334
# 112 / 234  processing:  PDAC_FS-07_337
# 113 / 234  processing:  PDAC_FS-07_340
# 114 / 234  processing:  PDAC_FS-07_343
# 115 / 234  processing:  PDAC_FS-07_346
# 116 / 234  processing:  PDAC_FS-07_349
# 117 / 234  processing:  PDAC_FS-07_352
# 118 / 234  processing:  PDAC_FS-07_355
# 119 / 234  processing:  PDAC_FS-07_358
# 120 / 234  processing:  PDAC_FS-07_361
# 121 / 234  processing:  PDAC_FS-07_364
# 122 / 234  processing:  PDAC_FS-07_367
# 123 / 234  processing:  PDAC_FS-07_370
# 124 / 234  processing:  PDAC_FS-07_373
# 125 / 234  processing:  PDAC_FS-07_376
# 126 / 234  processing:  PDAC_FS-07_379
# 127 / 234  processing:  PDAC_FS-07_382
# 128 / 234  processing:  PDAC_FS-07_385
# 129 / 234  processing:  PDAC_FS-07_388
# 130 / 234  processing:  PDAC_FS-07_391
# 131 / 234  processing:  PDAC_FS-07_394
# 132 / 234  processing:  PDAC_FS-07_397
# 133 / 234  processing:  PDAC_FS-07_400
# 134 / 234  processing:  PDAC_FS-07_403
# 135 / 234  processing:  PDAC_FS-07_406
# 136 / 234  processing:  PDAC_FS-07_409
# 137 / 234  processing:  PDAC_FS-07_412
# 138 / 234  processing:  PDAC_FS-07_415
# 139 / 234  processing:  PDAC_FS-07_418
# 140 / 234  processing:  PDAC_FS-07_421
# 141 / 234  processing:  PDAC_FS-07_424
# 142 / 234  processing:  PDAC_FS-07_427
# 143 / 234  processing:  PDAC_FS-07_430
# 144 / 234  processing:  PDAC_FS-07_433
# 145 / 234  processing:  PDAC_FS-07_436
# 146 / 234  processing:  PDAC_FS-07_439
# 147 / 234  processing:  PDAC_FS-07_442
# 148 / 234  processing:  PDAC_FS-07_445
# 149 / 234  processing:  PDAC_FS-07_448
# 150 / 234  processing:  PDAC_FS-07_451
# 151 / 234  processing:  PDAC_FS-07_454
# 152 / 234  processing:  PDAC_FS-07_457
# 153 / 234  processing:  PDAC_FS-07_460
# 154 / 234  processing:  PDAC_FS-07_463
# 155 / 234  processing:  PDAC_FS-07_466
# 156 / 234  processing:  PDAC_FS-07_469
# 157 / 234  processing:  PDAC_FS-07_472
# 158 / 234  processing:  PDAC_FS-07_475
# 159 / 234  processing:  PDAC_FS-07_478
# 160 / 234  processing:  PDAC_FS-07_481
# 161 / 234  processing:  PDAC_FS-07_484
# 162 / 234  processing:  PDAC_FS-07_487
# 163 / 234  processing:  PDAC_FS-07_490
# 164 / 234  processing:  PDAC_FS-07_493
# 165 / 234  processing:  PDAC_FS-07_496
# 166 / 234  processing:  PDAC_FS-07_499
# 167 / 234  processing:  PDAC_FS-07_502
# 168 / 234  processing:  PDAC_FS-07_505
# 169 / 234  processing:  PDAC_FS-07_508
# 170 / 234  processing:  PDAC_FS-07_511
# 171 / 234  processing:  PDAC_FS-07_514
# 172 / 234  processing:  PDAC_FS-07_517
# 173 / 234  processing:  PDAC_FS-07_520
# 174 / 234  processing:  PDAC_FS-07_523
# 175 / 234  processing:  PDAC_FS-07_526
# 176 / 234  processing:  PDAC_FS-07_529
# 177 / 234  processing:  PDAC_FS-07_532
# 178 / 234  processing:  PDAC_FS-07_535
# 179 / 234  processing:  PDAC_FS-07_538
# 180 / 234  processing:  PDAC_FS-07_541
# 181 / 234  processing:  PDAC_FS-07_544
# 182 / 234  processing:  PDAC_FS-07_547
# 183 / 234  processing:  PDAC_FS-07_550
# 184 / 234  processing:  PDAC_FS-07_553
# 185 / 234  processing:  PDAC_FS-07_556
# 186 / 234  processing:  PDAC_FS-07_559
# 187 / 234  processing:  PDAC_FS-07_562
# 188 / 234  processing:  PDAC_FS-07_565
# 189 / 234  processing:  PDAC_FS-07_568
# 190 / 234  processing:  PDAC_FS-07_571
# 191 / 234  processing:  PDAC_FS-07_574
# 192 / 234  processing:  PDAC_FS-07_577
# 193 / 234  processing:  PDAC_FS-07_580
# 194 / 234  processing:  PDAC_FS-07_583
# 195 / 234  processing:  PDAC_FS-07_586
# 196 / 234  processing:  PDAC_FS-07_589
# 197 / 234  processing:  PDAC_FS-07_592
# 198 / 234  processing:  PDAC_FS-07_595
# 199 / 234  processing:  PDAC_FS-07_598
# 200 / 234  processing:  PDAC_FS-07_601
# 201 / 234  processing:  PDAC_FS-07_604
# 202 / 234  processing:  PDAC_FS-07_607
# 203 / 234  processing:  PDAC_FS-07_610
# 204 / 234  processing:  PDAC_FS-07_613
# 205 / 234  processing:  PDAC_FS-07_616
# 206 / 234  processing:  PDAC_FS-07_619
# 207 / 234  processing:  PDAC_FS-07_622
# 208 / 234  processing:  PDAC_FS-07_625
# 209 / 234  processing:  PDAC_FS-07_628
# 210 / 234  processing:  PDAC_FS-07_631
# 211 / 234  processing:  PDAC_FS-07_634
# 212 / 234  processing:  PDAC_FS-07_637
# 213 / 234  processing:  PDAC_FS-07_640
# 214 / 234  processing:  PDAC_FS-07_643
# 215 / 234  processing:  PDAC_FS-07_646
# 216 / 234  processing:  PDAC_FS-07_649
# 217 / 234  processing:  PDAC_FS-07_652
# 218 / 234  processing:  PDAC_FS-07_655
# 219 / 234  processing:  PDAC_FS-07_658
# 220 / 234  processing:  PDAC_FS-07_661
# 221 / 234  processing:  PDAC_FS-07_664
# 222 / 234  processing:  PDAC_FS-07_667
# 223 / 234  processing:  PDAC_FS-07_670
# 224 / 234  processing:  PDAC_FS-07_673
# 225 / 234  processing:  PDAC_FS-07_676
# 226 / 234  processing:  PDAC_FS-07_679
# 227 / 234  processing:  PDAC_FS-07_682
# 228 / 234  processing:  PDAC_FS-07_685
# 229 / 234  processing:  PDAC_FS-07_688
# 230 / 234  processing:  PDAC_FS-07_691
# 231 / 234  processing:  PDAC_FS-07_694
# 232 / 234  processing:  PDAC_FS-07_697
# 233 / 234  processing:  PDAC_FS-07_700
