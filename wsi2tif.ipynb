# %%
import os
from PIL import Image
import numpy as np

# import tensorflow as tf
# physical_devices = tf.config.list_physical_devices('GPU')
# print(tf.__version__)
OPENSLIDE_PATH= r'C:\Program Files\openslide-win64-20230414\bin'
os.environ['PATH'] = OPENSLIDE_PATH + ";" + os.environ['PATH']

if hasattr(os, 'add_dll_directory'):
    with os.add_dll_directory(OPENSLIDE_PATH):
        import openslide
else:
    import openslide

from openslide import OpenSlide

# %%
wsisrc = r'\\10.17.97.73\kiemen-lab-data\Yu Shen\Venous Invasion\PDAC-FS-9'
tenxsrc = os.path.join(wsisrc, '10X')
twosrc = os.path.join(wsisrc, '1X')
if not os.path.exists(tenxsrc):
    os.mkdir(tenxsrc)
if not os.path.exists(twosrc):
    os.mkdir(twosrc)

# %%
wsis = [_ for _ in os.listdir(wsisrc) if _.endswith('ndpi')]
wsis2 = [os.path.splitext(_)[0] for _ in wsis]
tenx = [_ for _ in os.listdir(tenxsrc) if _.endswith('tif')]
tenx2 = [os.path.splitext(_)[0] for _ in tenx]
missingimages = [_ for _ in wsis2 if _ not in tenx2]

# %%
for idx,missingimage in enumerate(missingimages):
    print(idx,'/',len(missingimages),' processing: ',missingimage)
    wsi = OpenSlide(os.path.join(wsisrc,missingimage+'.ndpi'))
    rsf = 1
    svs_img = wsi.read_region(location=(0,0),level=0,size=wsi.level_dimensions[0]).convert('RGB')
    resize_factorx = rsf/float(wsi.properties['openslide.mpp-x']) #8um = 1.25x #4um = 2.5x, #2um=5x, 1um=10x, 0.5um=20x, 0.25um=40x
    resize_factory = rsf/float(wsi.properties['openslide.mpp-y'])
    resize_dimension = tuple([int(np.ceil(wsi.dimensions[0]/resize_factorx)),int(np.ceil(wsi.dimensions[1]/resize_factory))])
    svs_img = svs_img.resize(resize_dimension,resample=Image.NEAREST) #overwrite svs_img to save memory
    svs_img.save(os.path.join(tenxsrc,missingimage+'.tif'),resolution=1,resolution_unit=1,quality=100,compression=None)



    rsf = 8
    resize_factorx = rsf/float(wsi.properties['openslide.mpp-x']) #8um = 1.25x #4um = 2.5x, #2um=5x, 1um=10x, 0.5um=20x, 0.25um=40x
    resize_factory = rsf/float(wsi.properties['openslide.mpp-y'])
    resize_dimension = tuple([int(np.ceil(wsi.dimensions[0]/resize_factorx)),int(np.ceil(wsi.dimensions[1]/resize_factory))])
    svs_img2_5x = svs_img.resize(resize_dimension,resample=Image.NEAREST)
    svs_img2_5x.save(os.path.join(twosrc,missingimage+'.tif'),resolution=2_5,resolution_unit=1,quality=100,compression=None)

    # rsf = 8
    # # for diabete study, rsf = 5; for vi study, rsf = 8
    # resize_factorx = resize_factorx*rsf #8um = 1.25x # 5um = 2x #4um = 2.5x, #2um=5x, 1um=10x, 0.5um=20x, 0.25um=40x
    # resize_factory = resize_factory*rsf
    # resize_dimension = tuple([int(np.ceil(wsi.dimensions[0]/resize_factorx)),int(np.ceil(wsi.dimensions[1]/resize_factory))])
    # svs_img = svs_img.resize(resize_dimension,resample=Image.NEAREST)
    # svs_img.save(os.path.join(twosrc,missingimage+'.tif'),resolution=2_5,resolution_unit=1,quality=100,compression=None)
# Out:
# 0 / 234  processing:  PDAC_FS-09_001
# 1 / 234  processing:  PDAC_FS-09_004
# 2 / 234  processing:  PDAC_FS-09_007
# 3 / 234  processing:  PDAC_FS-09_010
# 4 / 234  processing:  PDAC_FS-09_013
# 5 / 234  processing:  PDAC_FS-09_016
# 6 / 234  processing:  PDAC_FS-09_019
# 7 / 234  processing:  PDAC_FS-09_022
# 8 / 234  processing:  PDAC_FS-09_025
# 9 / 234  processing:  PDAC_FS-09_028
# 10 / 234  processing:  PDAC_FS-09_031
# 11 / 234  processing:  PDAC_FS-09_034
# 12 / 234  processing:  PDAC_FS-09_037
# 13 / 234  processing:  PDAC_FS-09_040
# 14 / 234  processing:  PDAC_FS-09_043
# 15 / 234  processing:  PDAC_FS-09_046
# 16 / 234  processing:  PDAC_FS-09_049
# 17 / 234  processing:  PDAC_FS-09_052
# 18 / 234  processing:  PDAC_FS-09_055
# 19 / 234  processing:  PDAC_FS-09_058
# 20 / 234  processing:  PDAC_FS-09_061
# 21 / 234  processing:  PDAC_FS-09_064
# 22 / 234  processing:  PDAC_FS-09_067
# 23 / 234  processing:  PDAC_FS-09_070
# 24 / 234  processing:  PDAC_FS-09_073
# 25 / 234  processing:  PDAC_FS-09_076
# 26 / 234  processing:  PDAC_FS-09_079
# 27 / 234  processing:  PDAC_FS-09_082
# 28 / 234  processing:  PDAC_FS-09_085
# 29 / 234  processing:  PDAC_FS-09_088
# 30 / 234  processing:  PDAC_FS-09_091
# 31 / 234  processing:  PDAC_FS-09_094
# 32 / 234  processing:  PDAC_FS-09_097
# 33 / 234  processing:  PDAC_FS-09_100
# 34 / 234  processing:  PDAC_FS-09_103
# 35 / 234  processing:  PDAC_FS-09_106
# 36 / 234  processing:  PDAC_FS-09_109
# 37 / 234  processing:  PDAC_FS-09_112
# 38 / 234  processing:  PDAC_FS-09_115
# 39 / 234  processing:  PDAC_FS-09_118
# 40 / 234  processing:  PDAC_FS-09_121
# 41 / 234  processing:  PDAC_FS-09_124
# 42 / 234  processing:  PDAC_FS-09_127
# 43 / 234  processing:  PDAC_FS-09_130
# 44 / 234  processing:  PDAC_FS-09_133
# 45 / 234  processing:  PDAC_FS-09_136
# 46 / 234  processing:  PDAC_FS-09_139
# 47 / 234  processing:  PDAC_FS-09_142
# 48 / 234  processing:  PDAC_FS-09_145
# 49 / 234  processing:  PDAC_FS-09_148
# 50 / 234  processing:  PDAC_FS-09_151
# 51 / 234  processing:  PDAC_FS-09_154
# 52 / 234  processing:  PDAC_FS-09_157
# 53 / 234  processing:  PDAC_FS-09_160
# 54 / 234  processing:  PDAC_FS-09_163
# 55 / 234  processing:  PDAC_FS-09_166
# 56 / 234  processing:  PDAC_FS-09_169
# 57 / 234  processing:  PDAC_FS-09_172
# 58 / 234  processing:  PDAC_FS-09_175
# 59 / 234  processing:  PDAC_FS-09_178
# 60 / 234  processing:  PDAC_FS-09_181
# 61 / 234  processing:  PDAC_FS-09_184
# 62 / 234  processing:  PDAC_FS-09_187
# 63 / 234  processing:  PDAC_FS-09_190
# 64 / 234  processing:  PDAC_FS-09_193
# 65 / 234  processing:  PDAC_FS-09_196
# 66 / 234  processing:  PDAC_FS-09_199
# 67 / 234  processing:  PDAC_FS-09_202
# 68 / 234  processing:  PDAC_FS-09_205
# 69 / 234  processing:  PDAC_FS-09_208
# 70 / 234  processing:  PDAC_FS-09_211
# 71 / 234  processing:  PDAC_FS-09_214
# 72 / 234  processing:  PDAC_FS-09_217
# 73 / 234  processing:  PDAC_FS-09_220
# 74 / 234  processing:  PDAC_FS-09_223
# 75 / 234  processing:  PDAC_FS-09_226
# 76 / 234  processing:  PDAC_FS-09_229
# 77 / 234  processing:  PDAC_FS-09_232
# 78 / 234  processing:  PDAC_FS-09_235
# 79 / 234  processing:  PDAC_FS-09_238
# 80 / 234  processing:  PDAC_FS-09_241
# 81 / 234  processing:  PDAC_FS-09_244
# 82 / 234  processing:  PDAC_FS-09_247
# 83 / 234  processing:  PDAC_FS-09_250
# 84 / 234  processing:  PDAC_FS-09_253
# 85 / 234  processing:  PDAC_FS-09_256
# 86 / 234  processing:  PDAC_FS-09_259
# 87 / 234  processing:  PDAC_FS-09_262
# 88 / 234  processing:  PDAC_FS-09_265
# 89 / 234  processing:  PDAC_FS-09_268
# 90 / 234  processing:  PDAC_FS-09_271
# 91 / 234  processing:  PDAC_FS-09_274
# 92 / 234  processing:  PDAC_FS-09_277
# 93 / 234  processing:  PDAC_FS-09_280
# 94 / 234  processing:  PDAC_FS-09_283
# 95 / 234  processing:  PDAC_FS-09_286
# 96 / 234  processing:  PDAC_FS-09_289
# 97 / 234  processing:  PDAC_FS-09_292
# 98 / 234  processing:  PDAC_FS-09_295
# 99 / 234  processing:  PDAC_FS-09_298
# 100 / 234  processing:  PDAC_FS-09_301
# 101 / 234  processing:  PDAC_FS-09_304
# 102 / 234  processing:  PDAC_FS-09_307
# 103 / 234  processing:  PDAC_FS-09_310
# 104 / 234  processing:  PDAC_FS-09_313
# 105 / 234  processing:  PDAC_FS-09_316
# 106 / 234  processing:  PDAC_FS-09_319
# 107 / 234  processing:  PDAC_FS-09_322
# 108 / 234  processing:  PDAC_FS-09_325
# 109 / 234  processing:  PDAC_FS-09_328
# 110 / 234  processing:  PDAC_FS-09_331
# 111 / 234  processing:  PDAC_FS-09_334
# 112 / 234  processing:  PDAC_FS-09_337
# 113 / 234  processing:  PDAC_FS-09_340
# 114 / 234  processing:  PDAC_FS-09_343
# 115 / 234  processing:  PDAC_FS-09_346
# 116 / 234  processing:  PDAC_FS-09_349
# 117 / 234  processing:  PDAC_FS-09_352
# 118 / 234  processing:  PDAC_FS-09_355
# 119 / 234  processing:  PDAC_FS-09_358
# 120 / 234  processing:  PDAC_FS-09_361
# 121 / 234  processing:  PDAC_FS-09_364
# 122 / 234  processing:  PDAC_FS-09_367
# 123 / 234  processing:  PDAC_FS-09_370
# 124 / 234  processing:  PDAC_FS-09_373
# 125 / 234  processing:  PDAC_FS-09_376
# 126 / 234  processing:  PDAC_FS-09_379
# 127 / 234  processing:  PDAC_FS-09_382
# 128 / 234  processing:  PDAC_FS-09_385
# 129 / 234  processing:  PDAC_FS-09_388
# 130 / 234  processing:  PDAC_FS-09_391
# 131 / 234  processing:  PDAC_FS-09_394
# 132 / 234  processing:  PDAC_FS-09_397
# 133 / 234  processing:  PDAC_FS-09_400
# 134 / 234  processing:  PDAC_FS-09_403
# 135 / 234  processing:  PDAC_FS-09_406
# 136 / 234  processing:  PDAC_FS-09_409
# 137 / 234  processing:  PDAC_FS-09_412
# 138 / 234  processing:  PDAC_FS-09_415
# 139 / 234  processing:  PDAC_FS-09_418
# 140 / 234  processing:  PDAC_FS-09_421
# 141 / 234  processing:  PDAC_FS-09_424
# 142 / 234  processing:  PDAC_FS-09_427
# 143 / 234  processing:  PDAC_FS-09_430
# 144 / 234  processing:  PDAC_FS-09_433
# 145 / 234  processing:  PDAC_FS-09_436
# 146 / 234  processing:  PDAC_FS-09_439
# 147 / 234  processing:  PDAC_FS-09_442
# 148 / 234  processing:  PDAC_FS-09_445
# 149 / 234  processing:  PDAC_FS-09_448
# 150 / 234  processing:  PDAC_FS-09_451
# 151 / 234  processing:  PDAC_FS-09_454
# 152 / 234  processing:  PDAC_FS-09_457
# 153 / 234  processing:  PDAC_FS-09_460
# 154 / 234  processing:  PDAC_FS-09_463
# 155 / 234  processing:  PDAC_FS-09_466
# 156 / 234  processing:  PDAC_FS-09_469
# 157 / 234  processing:  PDAC_FS-09_472
# 158 / 234  processing:  PDAC_FS-09_475
# 159 / 234  processing:  PDAC_FS-09_478
# 160 / 234  processing:  PDAC_FS-09_481
# 161 / 234  processing:  PDAC_FS-09_484
# 162 / 234  processing:  PDAC_FS-09_487
# 163 / 234  processing:  PDAC_FS-09_490
# 164 / 234  processing:  PDAC_FS-09_493
# 165 / 234  processing:  PDAC_FS-09_496
# 166 / 234  processing:  PDAC_FS-09_499
# 167 / 234  processing:  PDAC_FS-09_502
# 168 / 234  processing:  PDAC_FS-09_505
# 169 / 234  processing:  PDAC_FS-09_508
# 170 / 234  processing:  PDAC_FS-09_511
# 171 / 234  processing:  PDAC_FS-09_514
# 172 / 234  processing:  PDAC_FS-09_517
# 173 / 234  processing:  PDAC_FS-09_520
# 174 / 234  processing:  PDAC_FS-09_523
# 175 / 234  processing:  PDAC_FS-09_526
# 176 / 234  processing:  PDAC_FS-09_529
# 177 / 234  processing:  PDAC_FS-09_532
# 178 / 234  processing:  PDAC_FS-09_535
# 179 / 234  processing:  PDAC_FS-09_538
# 180 / 234  processing:  PDAC_FS-09_541
# 181 / 234  processing:  PDAC_FS-09_544
# 182 / 234  processing:  PDAC_FS-09_547
# 183 / 234  processing:  PDAC_FS-09_550
# 184 / 234  processing:  PDAC_FS-09_553
# 185 / 234  processing:  PDAC_FS-09_556
# 186 / 234  processing:  PDAC_FS-09_559
# 187 / 234  processing:  PDAC_FS-09_562
# 188 / 234  processing:  PDAC_FS-09_565
# 189 / 234  processing:  PDAC_FS-09_568
# 190 / 234  processing:  PDAC_FS-09_571
# 191 / 234  processing:  PDAC_FS-09_574
# 192 / 234  processing:  PDAC_FS-09_577
# 193 / 234  processing:  PDAC_FS-09_580
# 194 / 234  processing:  PDAC_FS-09_583
# 195 / 234  processing:  PDAC_FS-09_586
# 196 / 234  processing:  PDAC_FS-09_589
# 197 / 234  processing:  PDAC_FS-09_592
# 198 / 234  processing:  PDAC_FS-09_595
# 199 / 234  processing:  PDAC_FS-09_598
# 200 / 234  processing:  PDAC_FS-09_601
# 201 / 234  processing:  PDAC_FS-09_604
# 202 / 234  processing:  PDAC_FS-09_607
# 203 / 234  processing:  PDAC_FS-09_610
# 204 / 234  processing:  PDAC_FS-09_613
# 205 / 234  processing:  PDAC_FS-09_616
# 206 / 234  processing:  PDAC_FS-09_619
# 207 / 234  processing:  PDAC_FS-09_622
# 208 / 234  processing:  PDAC_FS-09_625
# 209 / 234  processing:  PDAC_FS-09_628
# 210 / 234  processing:  PDAC_FS-09_631
# 211 / 234  processing:  PDAC_FS-09_634
# 212 / 234  processing:  PDAC_FS-09_637
# 213 / 234  processing:  PDAC_FS-09_640
# 214 / 234  processing:  PDAC_FS-09_643
# 215 / 234  processing:  PDAC_FS-09_646
# 216 / 234  processing:  PDAC_FS-09_652
# 217 / 234  processing:  PDAC_FS-09_655
# 218 / 234  processing:  PDAC_FS-09_658
# 219 / 234  processing:  PDAC_FS-09_661
# 220 / 234  processing:  PDAC_FS-09_664
# 221 / 234  processing:  PDAC_FS-09_667
# 222 / 234  processing:  PDAC_FS-09_670
# 223 / 234  processing:  PDAC_FS-09_673
# 224 / 234  processing:  PDAC_FS-09_676
# 225 / 234  processing:  PDAC_FS-09_679
# 226 / 234  processing:  PDAC_FS-09_682
# 227 / 234  processing:  PDAC_FS-09_685
# 228 / 234  processing:  PDAC_FS-09_688
# 229 / 234  processing:  PDAC_FS-09_691
# 230 / 234  processing:  PDAC_FS-09_694
# 231 / 234  processing:  PDAC_FS-09_697
# 232 / 234  processing:  PDAC_FS-09_700
# 233 / 234  processing:  PDAC_FS-09_703
