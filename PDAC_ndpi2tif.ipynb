# %%
# import packages
import os
from PIL import Image
import numpy as np

# import tensorflow as tf
# physical_devices = tf.config.list_physical_devices('GPU')
# print(tf.__version__)
OPENSLIDE_PATH = r'C:\Program Files\openslide-win64-20230414\bin'

os.environ['PATH'] = OPENSLIDE_PATH + ";" + os.environ['PATH']

if hasattr(os, 'add_dll_directory'):
    with os.add_dll_directory(OPENSLIDE_PATH):
        import openslide
else:
    import openslide

from openslide import OpenSlide

# %%
# set output path for 10x and 2x tif images - create directory if they don't exist
WSI_path = r'\\10.17.97.73\kiemen-lab-data\Yu Shen\Venous Invasion\PDAC-FS-7'
path_10x = os.path.join(WSI_path, '10X')
path_2x = os.path.join(WSI_path, '1X')  # actually 2.5
if not os.path.exists(path_10x):
    os.mkdir(path_10x)
if not os.path.exists(path_2x):
    os.mkdir(path_2x)

# %%
# find missing images -> code will continue with the missing ones and skip the ones that are existed
wsis = [_ for _ in os.listdir(WSI_path) if _.endswith('ndpi')]
wsis2 = [os.path.splitext(_)[0] for _ in wsis]
tenx = [_ for _ in os.listdir(path_10x) if _.endswith('tif')]
tenx2 = [os.path.splitext(_)[0] for _ in tenx]
missingimages = [_ for _ in wsis2 if _ not in tenx2]

# %%
for idx, missingimage in enumerate(missingimages):
    print(idx, '/', len(missingimages), ' processing: ', missingimage)
    wsi = OpenSlide(os.path.join(WSI_path, missingimage + '.ndpi'))

    rsf = 1
    svs_img = wsi.read_region(location=(0, 0), level=0, size=wsi.level_dimensions[0]).convert('RGB')
    resize_factorx = rsf / float(wsi.properties['openslide.mpp-x'])  #8um = 1.25x #4um = 2.5x, #2um=5x, 1um=10x, 0.5um=20x, 0.25um=40x
    resize_factory = rsf / float(wsi.properties['openslide.mpp-y'])
    resize_dimension = tuple([int(np.ceil(wsi.dimensions[0] / resize_factorx)), int(np.ceil(wsi.dimensions[1] / resize_factory))])
    svs_img10x = svs_img.resize(resize_dimension, resample=Image.NEAREST)
    svs_img10x.save(os.path.join(path_10x, missingimage + '.tif'), resolution=1, resolution_unit=1, quality=100, compression=None)

    rsf = 8
    resize_factorx = rsf / float(wsi.properties['openslide.mpp-x'])  #8um = 1.25x #4um = 2.5x, #2um=5x, 1um=10x, 0.5um=20x, 0.25um=40x
    resize_factory = rsf / float(wsi.properties['openslide.mpp-y'])
    resize_dimension = tuple([int(np.ceil(wsi.dimensions[0] / resize_factorx)), int(np.ceil(wsi.dimensions[1] / resize_factory))])
    svs_img2_5x = svs_img.resize(resize_dimension, resample=Image.NEAREST)
    svs_img2_5x.save(os.path.join(path_2x, missingimage + '.tif'), resolution=2_5, resolution_unit=1, quality=100, compression=None)
# Out:
# 0 / 184  processing:  PDAC_FS-34_001
# 1 / 184  processing:  PDAC_FS-34_004
# 2 / 184  processing:  PDAC_FS-34_007
# 3 / 184  processing:  PDAC_FS-34_010
# 4 / 184  processing:  PDAC_FS-34_013
# 5 / 184  processing:  PDAC_FS-34_016
# 6 / 184  processing:  PDAC_FS-34_019
# 7 / 184  processing:  PDAC_FS-34_022
# 8 / 184  processing:  PDAC_FS-34_025
# 9 / 184  processing:  PDAC_FS-34_028
# 10 / 184  processing:  PDAC_FS-34_031
# 11 / 184  processing:  PDAC_FS-34_034
# 12 / 184  processing:  PDAC_FS-34_037
# 13 / 184  processing:  PDAC_FS-34_040
# 14 / 184  processing:  PDAC_FS-34_043
# 15 / 184  processing:  PDAC_FS-34_046
# 16 / 184  processing:  PDAC_FS-34_049
# 17 / 184  processing:  PDAC_FS-34_052
# 18 / 184  processing:  PDAC_FS-34_055
# 19 / 184  processing:  PDAC_FS-34_058
# 20 / 184  processing:  PDAC_FS-34_061
# 21 / 184  processing:  PDAC_FS-34_064
# 22 / 184  processing:  PDAC_FS-34_067
# 23 / 184  processing:  PDAC_FS-34_070
# 24 / 184  processing:  PDAC_FS-34_073
# 25 / 184  processing:  PDAC_FS-34_076
# 26 / 184  processing:  PDAC_FS-34_079
# 27 / 184  processing:  PDAC_FS-34_082
# 28 / 184  processing:  PDAC_FS-34_085
# 29 / 184  processing:  PDAC_FS-34_088
# 30 / 184  processing:  PDAC_FS-34_091
# 31 / 184  processing:  PDAC_FS-34_094
# 32 / 184  processing:  PDAC_FS-34_097
# 33 / 184  processing:  PDAC_FS-34_100
# 34 / 184  processing:  PDAC_FS-34_103
# 35 / 184  processing:  PDAC_FS-34_106
# 36 / 184  processing:  PDAC_FS-34_109
# 37 / 184  processing:  PDAC_FS-34_112
# 38 / 184  processing:  PDAC_FS-34_115
# 39 / 184  processing:  PDAC_FS-34_118
# 40 / 184  processing:  PDAC_FS-34_121
# 41 / 184  processing:  PDAC_FS-34_124
# 42 / 184  processing:  PDAC_FS-34_127
# 43 / 184  processing:  PDAC_FS-34_130
# 44 / 184  processing:  PDAC_FS-34_133
# 45 / 184  processing:  PDAC_FS-34_136
# 46 / 184  processing:  PDAC_FS-34_139
# 47 / 184  processing:  PDAC_FS-34_142
# 48 / 184  processing:  PDAC_FS-34_145
# 49 / 184  processing:  PDAC_FS-34_148
# 50 / 184  processing:  PDAC_FS-34_151
# 51 / 184  processing:  PDAC_FS-34_154
# 52 / 184  processing:  PDAC_FS-34_157
# 53 / 184  processing:  PDAC_FS-34_160
# 54 / 184  processing:  PDAC_FS-34_163
# 55 / 184  processing:  PDAC_FS-34_166
# 56 / 184  processing:  PDAC_FS-34_169
# 57 / 184  processing:  PDAC_FS-34_172
# 58 / 184  processing:  PDAC_FS-34_175
# 59 / 184  processing:  PDAC_FS-34_178
# 60 / 184  processing:  PDAC_FS-34_181
# 61 / 184  processing:  PDAC_FS-34_184
# 62 / 184  processing:  PDAC_FS-34_187
# 63 / 184  processing:  PDAC_FS-34_190
# 64 / 184  processing:  PDAC_FS-34_193
# 65 / 184  processing:  PDAC_FS-34_196
# 66 / 184  processing:  PDAC_FS-34_199
# 67 / 184  processing:  PDAC_FS-34_202
# 68 / 184  processing:  PDAC_FS-34_205
# 69 / 184  processing:  PDAC_FS-34_208
# 70 / 184  processing:  PDAC_FS-34_211
# 71 / 184  processing:  PDAC_FS-34_214
# 72 / 184  processing:  PDAC_FS-34_217
# 73 / 184  processing:  PDAC_FS-34_220
# 74 / 184  processing:  PDAC_FS-34_223
# 75 / 184  processing:  PDAC_FS-34_226
# 76 / 184  processing:  PDAC_FS-34_229
# 77 / 184  processing:  PDAC_FS-34_232
# 78 / 184  processing:  PDAC_FS-34_235
# 79 / 184  processing:  PDAC_FS-34_238
# 80 / 184  processing:  PDAC_FS-34_241
# 81 / 184  processing:  PDAC_FS-34_244
# 82 / 184  processing:  PDAC_FS-34_247
# 83 / 184  processing:  PDAC_FS-34_250
# 84 / 184  processing:  PDAC_FS-34_253
# 85 / 184  processing:  PDAC_FS-34_256
# 86 / 184  processing:  PDAC_FS-34_259
# 87 / 184  processing:  PDAC_FS-34_262
# 88 / 184  processing:  PDAC_FS-34_265
# 89 / 184  processing:  PDAC_FS-34_268
# 90 / 184  processing:  PDAC_FS-34_271
# 91 / 184  processing:  PDAC_FS-34_274
# 92 / 184  processing:  PDAC_FS-34_277
# 93 / 184  processing:  PDAC_FS-34_280
# 94 / 184  processing:  PDAC_FS-34_283
# 95 / 184  processing:  PDAC_FS-34_286
# 96 / 184  processing:  PDAC_FS-34_289
# 97 / 184  processing:  PDAC_FS-34_292
# 98 / 184  processing:  PDAC_FS-34_295
# 99 / 184  processing:  PDAC_FS-34_298
# 100 / 184  processing:  PDAC_FS-34_301
# 101 / 184  processing:  PDAC_FS-34_304
# 102 / 184  processing:  PDAC_FS-34_307
# 103 / 184  processing:  PDAC_FS-34_310
# 104 / 184  processing:  PDAC_FS-34_313
# 105 / 184  processing:  PDAC_FS-34_316
# 106 / 184  processing:  PDAC_FS-34_319
# 107 / 184  processing:  PDAC_FS-34_322
# 108 / 184  processing:  PDAC_FS-34_325
# 109 / 184  processing:  PDAC_FS-34_328
# 110 / 184  processing:  PDAC_FS-34_331
# 111 / 184  processing:  PDAC_FS-34_334
# 112 / 184  processing:  PDAC_FS-34_337
# 113 / 184  processing:  PDAC_FS-34_340
# 114 / 184  processing:  PDAC_FS-34_343
# 115 / 184  processing:  PDAC_FS-34_346
# 116 / 184  processing:  PDAC_FS-34_349
# 117 / 184  processing:  PDAC_FS-34_352
# 118 / 184  processing:  PDAC_FS-34_355
# 119 / 184  processing:  PDAC_FS-34_358
# 120 / 184  processing:  PDAC_FS-34_361
# 121 / 184  processing:  PDAC_FS-34_364
# 122 / 184  processing:  PDAC_FS-34_367
# 123 / 184  processing:  PDAC_FS-34_370
# 124 / 184  processing:  PDAC_FS-34_373
# 125 / 184  processing:  PDAC_FS-34_376
# 126 / 184  processing:  PDAC_FS-34_379
# 127 / 184  processing:  PDAC_FS-34_382
# 128 / 184  processing:  PDAC_FS-34_385
# 129 / 184  processing:  PDAC_FS-34_388
# 130 / 184  processing:  PDAC_FS-34_391
# 131 / 184  processing:  PDAC_FS-34_394
# 132 / 184  processing:  PDAC_FS-34_397
# 133 / 184  processing:  PDAC_FS-34_400
# 134 / 184  processing:  PDAC_FS-34_403
# 135 / 184  processing:  PDAC_FS-34_406
# 136 / 184  processing:  PDAC_FS-34_409
# 137 / 184  processing:  PDAC_FS-34_412
# 138 / 184  processing:  PDAC_FS-34_415
# 139 / 184  processing:  PDAC_FS-34_418
# 140 / 184  processing:  PDAC_FS-34_421
# 141 / 184  processing:  PDAC_FS-34_424
# 142 / 184  processing:  PDAC_FS-34_427
# 143 / 184  processing:  PDAC_FS-34_430
# 144 / 184  processing:  PDAC_FS-34_433
# 145 / 184  processing:  PDAC_FS-34_436
# 146 / 184  processing:  PDAC_FS-34_439
# 147 / 184  processing:  PDAC_FS-34_442
# 148 / 184  processing:  PDAC_FS-34_445
# 149 / 184  processing:  PDAC_FS-34_448
# 150 / 184  processing:  PDAC_FS-34_451
# 151 / 184  processing:  PDAC_FS-34_454
# 152 / 184  processing:  PDAC_FS-34_457
# 153 / 184  processing:  PDAC_FS-34_460
# 154 / 184  processing:  PDAC_FS-34_463
# 155 / 184  processing:  PDAC_FS-34_466
# 156 / 184  processing:  PDAC_FS-34_469
# 157 / 184  processing:  PDAC_FS-34_472
# 158 / 184  processing:  PDAC_FS-34_475
# 159 / 184  processing:  PDAC_FS-34_478
# 160 / 184  processing:  PDAC_FS-34_481
# 161 / 184  processing:  PDAC_FS-34_484
# 162 / 184  processing:  PDAC_FS-34_487
# 163 / 184  processing:  PDAC_FS-34_490
# 164 / 184  processing:  PDAC_FS-34_493
# 165 / 184  processing:  PDAC_FS-34_496
# 166 / 184  processing:  PDAC_FS-34_499
# 167 / 184  processing:  PDAC_FS-34_502
# 168 / 184  processing:  PDAC_FS-34_505
# 169 / 184  processing:  PDAC_FS-34_508
# 170 / 184  processing:  PDAC_FS-34_511
# 171 / 184  processing:  PDAC_FS-34_514
# 172 / 184  processing:  PDAC_FS-34_517
# 173 / 184  processing:  PDAC_FS-34_520
# 174 / 184  processing:  PDAC_FS-34_523
# 175 / 184  processing:  PDAC_FS-34_526
# 176 / 184  processing:  PDAC_FS-34_529
# 177 / 184  processing:  PDAC_FS-34_532
# 178 / 184  processing:  PDAC_FS-34_535
# 179 / 184  processing:  PDAC_FS-34_538
# 180 / 184  processing:  PDAC_FS-34_541
# 181 / 184  processing:  PDAC_FS-34_544
# 182 / 184  processing:  PDAC_FS-34_547
# 183 / 184  processing:  PDAC_FS-34_550
